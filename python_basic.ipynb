# %% [markdown]
# ## DataTypes

# %%
## integer example

age = 35
type(age)
# Out:
# int

# %%
## folating point datatype

height = 5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
## string data type example 
name = "ali"
print(name)
print(type(name))
# Out:
# ali
# <class 'str'>

# %%
## boolean datatype
is_true= True
type(is_true)
# Out:
# bool

# %%
bool()
# Out:
# False

# %%
a = 10
b = 10
a==b
# Out:
# True

# %%
type(a==b)
# Out:
# bool

# %%
## common errors
result = "hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 ## common errors
# ----> 2 result = "hello" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "hello" + str(5) 
print(result)
# Out:
# hello5
